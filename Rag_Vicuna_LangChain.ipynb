# %%
# !pip install -q transformers==4.41.2
# !pip install -q bitsandbytes==0.43.1
# !pip install -q accelerate==0.31.0
# !pip install -q langchain==0.2.5
# !pip install -q langchainhub==0.1.20
# !pip install -q langchain-chroma==0.1.1
# !pip install -q langchain-community==0.2.5
# !pip install -q langchain_huggingface==0.0.3
# !pip install -q python-dotenv ==1.0.1
# !pip install -q pypdf==4.2.0
# !pip install -q numpy==1.24.4
# !pip install -q chainlit==1.1.304
# !pip install pyngrok -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 1.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 68.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.4/337.4 kB 29.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.5/127.5 kB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 93.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 10.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 22.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 55.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 31.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 17.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 33.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 93.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 77.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 19.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.0 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 39.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 7.5 MB/s eta 0:00:00
# ERROR: Invalid requirement: '==1.0.1'
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 53.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 52.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 52.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 7.9 MB/s eta 0:00:00
#   Building wheel for literalai (setup.py) ... done
#   Building wheel for syncer (setup.py) ... done

# %%
import torch

from transformers import BitsAndBytesConfig
from transformers import AutoTokenizer , AutoModelForCausalLM ,pipeline
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_huggingface.llms import HuggingFacePipeline

from langchain.memory import ConversationBufferMemory
from langchain_community . chat_message_histories import ChatMessageHistory
from langchain_community . document_loaders import PyPDFLoader ,TextLoader
from langchain . chains import ConversationalRetrievalChain

from langchain_chroma import Chroma
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core . runnables import RunnablePassthrough
from langchain_core . output_parsers import StrOutputParser
from langchain import hub

# %% [markdown]
# #database

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Loader = PyPDFLoader
FILE_PATH = "/content/drive/MyDrive/da cntt/Document-RAG/CÁC LIỆU PHÁP TÂM LÝ.pdf"
loader = Loader ( FILE_PATH )
documents = loader.load ()

# %% [markdown]
# #Text spliter

# %%
text_splitter = RecursiveCharacterTextSplitter ( chunk_size =1000 ,chunk_overlap =100)

# %%
docs = text_splitter.split_documents ( documents )

# %%
print (" Number of sub - documents : ", len( docs ) )
print ( docs [0])
# Out:
#  Number of sub - documents :  14
# page_content='- ATK mới: Olanzapine, Risperdal, Solian...    \n- Chỉnh khí sắc: Valproate, Carbamazepine...    \n- Chống trầm cảm: SSRI...    \nLiều lượng các thu ốc này tùy thu ộc từng bệnh nhân c ụ thể với nguyên t ắc ½ liều người trẻ.   \n- Thuốc nâng cao th ể trạng. \n \n \n48. CÁC LI ỆU PHÁP TÂM LÝ  \n \nCử nhân tâm lý  Đỗ Thị Thu H ồng \nBệnh vi ện Tâm th ần ban ngày Mai Hương  \n \nỞ Việt Nam trư ớc quá trình đ ổi mới và quá trình đô th ị hoá ngày càng gia tăng, s ức ép của công \nviệc, sức ép của những biến đổi xã hội tác động lên đời sống tình cảm của các cá nhân trong \nnhiều nhóm xã h ội khác nhau có th ể dẫn đến những biến đổi cảm xúc, sai l ệch hành vi , biến đổi \nnhân cách, ảnh hưởng tới sức khoẻ tâm thần của con ngư ời. Việc trị liệu tâm lý ngày càng có vai \ntrò quan tr ọng. Vậy trị liệu tâm lý là gì? Có nh ững hình th ức nào có th ể được áp dụng trong tr ị \nliệu tâm lý?  \nChúng ta có th ể hiểu trị liệu tâm lý là sự điều trị các rối loạn cảm xúc, hành vi, nhân cách và tâm' metadata={'source': '/content/drive/MyDrive/da cntt/Document-RAG/CÁC LIỆU PHÁP TÂM LÝ.pdf', 'page': 0}

# %% [markdown]
# #Khởi tạo instance vectorization:

# %%
embedding = HuggingFaceEmbeddings ()
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# #Khởi tạo vector database

# %%
vector_db = Chroma.from_documents ( documents =docs , embedding = embedding )

# %%
retriever = vector_db . as_retriever ()

# %%
result = retriever . invoke ("Vậy trị liệu tâm lý là gì? Có những hình thức nào có thể được áp dụng trong trị liệu tâm lý?")
print (" Number of relevant documents : ", len ( result ) )
# Out:
#  Number of relevant documents :  4

# %%
result #Kết quả của đoạn code này sẽ trả về cho ta danh sách các tài liệu có liên quan đến đoạn văn bản đầu vào.
# Out:
# [Document(page_content='- Theo dạng hoạt động: Trò chuy ện, trò chơi, hành vi, ngh ệ thuật: vẽ, âm nhạc, tâm kịch \nMột số hình th ức trị liệu tâm l{ đang đư ợc áp d ụng tại Bệnh vi ện tâm th ần ban ngày Mai \nHương:', metadata={'page': 1, 'source': '/content/drive/MyDrive/da cntt/Document-RAG/CÁC LIỆU PHÁP TÂM LÝ.pdf'}),
#  Document(page_content='bệnh trầm trọng, cấp tính.  \nĐiều trị bệnh TTPL ở cộng đồng bao gồm: \n1.Phục hồi chức năng tâm l{ xã h ội \n2.Phục hồi chức năng ngh ề nghiệp, lao động liệu pháp  \n3.Liệu pháp hoá dư ợc \n \nI- Phục hồi chức năng tâm l{ xã h ội \nNhư chúng ta bi ết bệnh nhân tâm th ần thường bị xã hội mặc cảm, miệt thị, mọi người xa lánh, \nít được tham gia các ho ạt động xã hội cũng như các ho ạt động nghề nghiệp. Nhưng ph ần lớn \nbệnh nhân tâm th ần lại sống ở gia đình, ở cộng đồng xã hội. Chính vì v ậy cần phải tuyên truy ền \ngiáo dục cho cộng đồng có thái đ ộ đúng đắn đối với người bệnh như lời khuyến cáo của WHO', metadata={'page': 3, 'source': '/content/drive/MyDrive/da cntt/Document-RAG/CÁC LIỆU PHÁP TÂM LÝ.pdf'}),
#  Document(page_content='thần thông qua giao ti ếp dùng ngôn ng ữ hay phi ngôn ng ữ với người bệnh. Trong th ực hành trị \nliệu tâm lý có th ể bao gồm cả việc chữa trị các rối loạn và giúp gư ời bệnh cách th ức giải quyết \ncác vấn đề trong cuộc sống. \nKhi bàn đ ến trị liệu tâm lý có m ột vấn đề chúng ta c ần quan tâm là tr ị liệu tâm l{ thư ờng bị \nnhầm với tư vấn. Điều này gây khó khăn trong vi ệc lựa chọn phương pháp can thi ệp. Tư vấn \nkhác với trị liệu tâm lý ở chỗ tư vấn là mối quan hệ và hoạt động mang tính chuyên môn mà \ntrong đó nhà tư v ấn giúp đối tượng hiểu và giải quyết việc điều chỉnh vấn đề, đưa ra lời khuyên, \nsự đánh giá, hay ch ỉ dẫn đối tượng cách đánh giá và ki ểm soát bản thân. Trong công tác tư v ấn \nnhà tư vấn thường đưa ra các phương án đ ể đối tượng lựa chọn phương án h ợp lý cho vi ệc \nquyết định, đánh giá m ột vấn đề gì đó.  \nTrị liệu tâm lý có hi ệu quả trong điều trị bệnh trầm cảm, lo âu, r ối loạn ám ảnh cưỡng bức, rối', metadata={'page': 0, 'source': '/content/drive/MyDrive/da cntt/Document-RAG/CÁC LIỆU PHÁP TÂM LÝ.pdf'}),
#  Document(page_content='hợp, sự phối hợp trị liệu tâm lý v ới điều trị thuốc tỏ ra có hiệu quả. Thuốc chống trầm cảm có \nthể nâng trạng thái cảm xúc, giúp  người bệnh tham gia tích c ực hơn vào quá trình tr ị liệu và đưa \nđến kết quả tốt hơn.  \nCó nhiều trường phái tâm lý, m ỗi trường phái có cách xây d ựng cơ sở lý thuyết khác nhau và \nđưa ra phương pháp tr ị liệu tâm l{ cũng r ất khác nhau.  \nMột số liệu pháp tâm lý  chính:  \nLiệu pháp phân tâm (phân tích tâm lý):  cho rằng người ta mắc bệnh là do nh ững xung đ ột giữa \nnhững nhu cầu, những mong mu ốn mang tính b ản năng với khả năng thoả mãn những nhu cầu, \nmong mu ốn đó. Ngư ời bệnh không ý th ức được những nguyên nhân này, nê n nhiệm vụ của nhà \ntrị liệu là bằng nghiệp vụ chuyên môn c ủa mình ph ải phát hiện ra những dồn nén, tức là những \nnguyên nhân gây b ệnh. Khi nguyên nhân đư ợc soi sáng trên bình di ện ý thức (được giải toả), thì \nxung đột sẽ hết, người bệnh sẽ khỏi bệnh.', metadata={'page': 1, 'source': '/content/drive/MyDrive/da cntt/Document-RAG/CÁC LIỆU PHÁP TÂM LÝ.pdf'})]

# %% [markdown]
# #Dùng vicuna

# %%
nf4_config = BitsAndBytesConfig (load_in_4bit =True , bnb_4bit_quant_type ="nf4", bnb_4bit_use_double_quant =True , bnb_4bit_compute_dtype = torch.bfloat16)

# %%
MODEL_NAME = "lmsys/vicuna-7b-v1.5"  # Remove extra spaces and invalid characters

model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME, quantization_config=nf4_config, low_cpu_mem_usage=True
)
# Out:
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/162 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# Out:
# tokenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]

# %%
model_pipeline = pipeline("text-generation", model =model , tokenizer = tokenizer ,max_new_tokens =512 ,pad_token_id = tokenizer . eos_token_id ,device_map ="auto" )

# %%
llm = HuggingFacePipeline (pipeline = model_pipeline)

# %%
prompt = hub.pull ("rlm/rag-prompt")

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

rag_chain = ({"context": retriever | format_docs, "question": RunnablePassthrough()}
             | prompt
             |llm
             | StrOutputParser())

# %%
USER_QUESTION = "Vậy trị liệu tâm lý là gì? Có những hình thức nào có thể được áp dụng trong trị liệu tâm lý?"
output = rag_chain.invoke(USER_QUESTION)
answer = output.split('Answer:')[1].strip ()
print(answer)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Trị liệu tâm lý là một phương pháp điều trị bệnh tâm thần, bao gồm các hoạt động như trò chuyện, trò chơi, hành vi, nghệ thuật và liệu pháp hoá. Có nhiều trường phái tâm lý với các phương pháp khác nhau như liệu pháp phân tâm.

# %% [markdown]
# #Giao diện

# %%
# !pip install -q chainlit==1.1.304
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 38.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 25.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 6.1 MB/s eta 0:00:00
#   Building wheel for literalai (setup.py) ... done
#   Building wheel for syncer (setup.py) ... done

# %%
import chainlit as cl
import torch

from chainlit . types import AskFileResponse

from transformers import BitsAndBytesConfig
from transformers import AutoTokenizer , AutoModelForCausalLM , pipeline
from langchain_huggingface . llms import HuggingFacePipeline

from langchain . memory import ConversationBufferMemory
from langchain_community . chat_message_histories import ChatMessageHistory

from langchain . chains import ConversationalRetrievalChain

from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_community . document_loaders import PyPDFLoader , TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core . runnables import RunnablePassthrough
from langchain_core . output_parsers import StrOutputParser
from langchain import hub

# %%
text_splitter = RecursiveCharacterTextSplitter ( chunk_size =1000 ,chunk_overlap =100)

# %%
embedding = HuggingFaceEmbeddings ()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# Xây dựng hàm xử lý file input đầu vào

# %%
def process_file ( file : AskFileResponse ) :
  if file.type == " text/plain":
    Loader = TextLoader
  elif file . type == "application/pdf":
    Loader = PyPDFLoader
  loader = Loader (file.path)
  documents = loader.load()
  docs = text_splitter.split_documents(documents)
  for i, doc in enumerate (docs):
    doc.metadata["source"] = f" source_ {i}"
  return docs

# %% [markdown]
# Xây dựng hàm khởi tạo Chroma database

# %%
def get_vector_db (file:AskFileResponse ):
  docs = process_file (file)  #hàm process_file() để xử lý file input và trả về các tài liệu nhỏ (docs).
  cl.user_session.set("docs", docs)
  vector_db = Chroma . from_documents ( documents =docs ,embedding = embedding )
  return vector_db

# %% [markdown]
# Khởi tạo mô hình ngôn ngữ lớn:

# %%
MODEL_NAME = "lmsys/vicuna-7b-v1.5"

# %%
def get_huggingface_llm ( model_name : str =MODEL_NAME, max_new_token : int = 512) :
  nf4_config = BitsAndBytesConfig(load_in_4bit =True ,bnb_4bit_quant_type ="nf4",bnb_4bit_use_double_quant =True ,bnb_4bit_compute_dtype = torch.bfloat16)
  model = AutoModelForCausalLM . from_pretrained(model_name, quantization_config=nf4_config, low_cpu_mem_usage=True)
  tokenizer = AutoTokenizer.from_pretrained(model_name)
  model_pipeline = pipeline("text-generation", model =model , tokenizer = tokenizer ,max_new_tokens =max_new_token ,pad_token_id = tokenizer.eos_token_id ,device_map ="auto" )
  llm = HuggingFacePipeline (pipeline = model_pipeline)
  return llm

# %%
LLM = get_huggingface_llm()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(

# %%
welcome_message = """ Welcome to the PDF QA! To get started :
  1. Upload a PDF or text file
  2. Ask a question about the file """

# %% [markdown]
# Khởi tạo hàm on_chat_start:

# %%
@cl.on_chat_start
async def on_chat_start():
  files = None
  while files is None:
    files = await cl. AskFileMessage(content = welcome_message ,accept =["text/plain", "application/pdf"] ,max_size_mb =20 ,timeout =180).send()
  file = files[0]
  msg = cl.Message(content = f"Processing...{file.name}...", disable_feedback=True)
  await msg.send()
  vector_db = await cl.make_async(get_vector_db(file))
  message_history = ChatMessageHistory()
  memory = ConversationBufferMemory(memory_key="chat_history", output_key =" answer ", chat_memory=message_history, return_messages =True)
  retriever = vector_db.as_retriever(search_type ="mmr",search_kwargs ={ 'k': 3})
  chain = ConversationalRetrievalChain . from_llm(llm =LLM,chain_type ="stuff",retriever = retriever ,memory =memory ,return_source_documents = True)
  msg.content = f"'{file.name} processed. You can now ask questions!"
  await msg.update()
  cl.user_session.set("chain", chain)

# %% [markdown]
# Khởi tạo hàm on_message:

# %%
@cl.on_message
async def on_message( message : cl.Message ):
  chain = cl.user_session.get("chain")
  cb = cl.user_session.get("chat_history")
  res = await chain.ainvoke( message.content , callbacks =[cb])
  answer = res["answer"]
  source_documents = res["source_documents"]
  text_elements = []
  if source_documents :
    for source_idx , source_doc in enumerate ( source_documents ):
      source_name = f" source_ { source_idx }"
      text_elements.append(cl.Text(content = source_doc.page_content ,name = source_name ))
      source_names = [ text_el.name for text_el in text_elements ]
      if source_names :
        answer += f"\ nSources : { ', '. join ( source_names )}"
      else:
        answer += "\nNo sources found "
  await cl.Message( content = answer , elements = text_elements ).send ()

# %% [markdown]
# #Chainlit

# %%
# %%writefile app.py
import chainlit as cl
import torch

from chainlit.types import AskFileResponse
from transformers import BitsAndBytesConfig, AutoTokenizer, AutoModelForCausalLM, pipeline
from langchain_huggingface.llms import HuggingFacePipeline
from langchain.memory import ConversationBufferMemory
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain.chains import ConversationalRetrievalChain
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_community.document_loaders import PyPDFLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain import hub

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
embedding = HuggingFaceEmbeddings()

def process_file(file: AskFileResponse):
    if file.type == "text/plain":
        Loader = TextLoader
    elif file.type == "application/pdf":
        Loader = PyPDFLoader
    loader = Loader(file.path)
    documents = loader.load()
    docs = text_splitter.split_documents(documents)
    for i, doc in enumerate(docs):
        doc.metadata["source"] = f"source_{i}"
    return docs

def get_vector_db(file: AskFileResponse):
    docs = process_file(file)
    cl.user_session.set("docs", docs)
    vector_db = Chroma.from_documents(documents=docs, embedding=embedding)
    return vector_db

MODEL_NAME = "lmsys/vicuna-7b-v1.5"
def get_huggingface_llm(model_name: str = MODEL_NAME, max_new_token: int = 512):
    nf4_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_use_double_quant=True,
        bnb_4bit_compute_dtype=torch.bfloat16
    )
    model = AutoModelForCausalLM.from_pretrained(model_name, quantization_config=nf4_config, low_cpu_mem_usage=True)
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model_pipeline = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_new_tokens=max_new_token,
        pad_token_id=tokenizer.eos_token_id,
        device_map="auto"
    )
    llm = HuggingFacePipeline(pipeline=model_pipeline)
    return llm

LLM = get_huggingface_llm()
welcome_message = """ Welcome to the PDF QA! To get started:
1. Upload a PDF or text file
2. Ask a question about the file """

@cl.on_chat_start
async def on_chat_start():
    files = None
    while files is None:
        files = await cl.AskFileMessage(
            content=welcome_message,
            accept=["text/plain", "application/pdf"],
            max_size_mb=20,
            timeout=180
        ).send()
    file = files[0]
    msg = cl.Message(content=f"Processing... {file.name}...", disable_feedback=True)
    await msg.send()

    vector_db = await cl.make_async(get_vector_db)(file)

    message_history = ChatMessageHistory()
    memory = ConversationBufferMemory(
        memory_key="chat_history",
        output_key="answer",
        chat_memory=message_history,
        return_messages=True
    )
    retriever = vector_db.as_retriever(search_type="mmr", search_kwargs={'k': 3})
    chain = ConversationalRetrievalChain.from_llm(
        llm=LLM,
        chain_type="stuff",
        retriever=retriever,
        memory=memory,
        return_source_documents=True
    )
    msg.content = f"'{file.name} processed. You can now ask questions!"
    await msg.update()
    cl.user_session.set("chain", chain)
    #cl.user_session.set("chat_history", message_history)

@cl.on_message
async def on_message(message: cl.Message):
    chain = cl.user_session.get("chain")
    cb = cl.user_session.get("chat_history")
    res =await chain.ainvoke(message.content, callbacks=[cb])
    answer = res["answer"]
    source_documents = res["source_documents"]
    text_elements = []
    if source_documents:
            for source_idx, source_doc in enumerate(source_documents):
                source_name = f"source_{source_idx}"
                text_elements.append(cl.Text(content=source_doc.page_content, name=source_name))
            source_names = [text_el.name for text_el in text_elements]
            if source_names:
                answer += f"\nSources: {', '.join(source_names)}"
            else:
                answer += "\nNo sources found"
    await cl.Message(content=answer, elements=text_elements).send()
# Out:
# Writing app.py

# %%
# !pip install pyngrok -q

# %%
#lấy key ở: https://dashboard.ngrok.com/login
# !ngrok config add-authtoken [your_key]
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok
ngrok_tunnel = ngrok.connect(8000)
print('Public URL:', ngrok_tunnel.public_url)
# Out:
# Public URL: https://7b28-34-126-168-60.ngrok-free.app

# %%
#sau khi hiện http://localhost:8000, thì vào publi url ở cell trên sẽ mở được app
# !chainlit run app.py
# Out:
# 2024-07-03 11:56:21 - Created default config file at /content/.chainlit/config.toml
# 2024-07-03 11:56:21 - Created default translation directory at /content/.chainlit/translations
# 2024-07-03 11:56:21 - Created default translation file at /content/.chainlit/translations/en-US.json
# 2024-07-03 11:56:28.825444: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-03 11:56:28.825489: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-03 11:56:28.967085: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-03 11:56:29.258621: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-03 11:56:30.537681: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-03 11:56:35 - Use pytorch device_name: cuda
# 2024-07-03 11:56:35 - Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# modules.json: 100% 349/349 [00:00<00:00, 2.67MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 751kB/s]
# README.md: 100% 10.6k/10.6k [00:00<00:00, 31.5MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 344kB/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 571/571 [00:00<00:00, 3.28MB/s]
# model.safetensors: 100% 438M/438M [00:01<00:00, 305MB/s]
# tokenizer_config.json: 100% 363/363 [00:00<00:00, 2.52MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 57.9MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 24.6MB/s]
# special_tokens_map.json: 100% 239/239 [00:00<00:00, 809kB/s]
# 1_Pooling/config.json: 100% 190/190 [00:00<00:00, 1.36MB/s]
# config.json: 100% 615/615 [00:00<00:00, 4.09MB/s]
# pytorch_model.bin.index.json: 100% 26.8k/26.8k [00:00<00:00, 96.4MB/s]
# Downloading shards:   0% 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0% 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0% 41.9M/9.98G [00:00<00:27, 360MB/s]
# pytorch_model-00001-of-00002.bin:   1% 83.9M/9.98G [00:00<00:26, 380MB/s]
# pytorch_model-00001-of-00002.bin:   1% 126M/9.98G [00:00<00:25, 382MB/s]
# pytorch_model-00001-of-00002.bin:   2% 168M/9.98G [00:00<00:30, 325MB/s]
# pytorch_model-00001-of-00002.bin:   2% 210M/9.98G [00:00<00:31, 308MB/s]
# pytorch_model-00001-of-00002.bin:   3% 252M/9.98G [00:00<00:30, 315MB/s]
# pytorch_model-00001-of-00002.bin:   3% 294M/9.98G [00:00<00:31, 307MB/s]
# pytorch_model-00001-of-00002.bin:   3% 325M/9.98G [00:01<00:31, 308MB/s]
# pytorch_model-00001-of-00002.bin:   4% 367M/9.98G [00:01<00:30, 317MB/s]
# pytorch_model-00001-of-00002.bin:   4% 409M/9.98G [00:01<00:30, 316MB/s]
# pytorch_model-00001-of-00002.bin:   5% 451M/9.98G [00:01<00:29, 326MB/s]
# pytorch_model-00001-of-00002.bin:   5% 493M/9.98G [00:01<00:31, 306MB/s]
# pytorch_model-00001-of-00002.bin:   5% 524M/9.98G [00:01<00:31, 299MB/s]
# pytorch_model-00001-of-00002.bin:   6% 566M/9.98G [00:01<00:29, 315MB/s]
# pytorch_model-00001-of-00002.bin:   6% 608M/9.98G [00:01<00:33, 278MB/s]
# pytorch_model-00001-of-00002.bin:   6% 640M/9.98G [00:02<00:37, 252MB/s]
# pytorch_model-00001-of-00002.bin:   7% 671M/9.98G [00:02<00:39, 234MB/s]
0.00/3.50G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   1% 31.5M/3.50G [00:00<00:14, 237MB/s]
# pytorch_model-00002-of-00002.bin:   2% 73.4M/3.50G [00:00<00:11, 290MB/s]
# pytorch_model-00002-of-00002.bin:   3% 115M/3.50G [00:00<00:11, 294MB/s]
# pytorch_model-00002-of-00002.bin:   4% 147M/3.50G [00:00<00:13, 251MB/s]
# pytorch_model-00002-of-00002.bin:   5% 178M/3.50G [00:00<00:13, 242MB/s]
# pytorch_model-00002-of-00002.bin:   6% 210M/3.50G [00:00<00:13, 243MB/s]
# pytorch_model-00002-of-00002.bin:   7% 241M/3.50G [00:00<00:13, 242MB/s]
# pytorch_model-00002-of-00002.bin:   8% 273M/3.50G [00:01<00:13, 247MB/s]
# pytorch_model-00002-of-00002.bin:   9% 304M/3.50G [00:01<00:13, 245MB/s]
# pytorch_model-00002-of-00002.bin:  10% 346M/3.50G [00:01<00:11, 273MB/s]
# pytorch_model-00002-of-00002.bin:  11% 377M/3.50G [00:01<00:11, 266MB/s]
# pytorch_model-00002-of-00002.bin:  12% 409M/3.50G [00:01<00:11, 261MB/s]
# pytorch_model-00002-of-00002.bin:  13% 451M/3.50G [00:01<00:11, 277MB/s]
# pytorch_model-00002-of-00002.bin:  14% 482M/3.50G [00:01<00:12, 250MB/s]
# pytorch_model-00002-of-00002.bin:  15% 514M/3.50G [00:02<00:12, 243MB/s]
# pytorch_model-00002-of-00002.bin:  16% 545M/3.50G [00:02<00:11, 253MB/s]
# pytorch_model-00002-of-00002.bin:  16% 577M/3.50G [00:02<00:12, 232MB/s]
# pytorch_model-00002-of-00002.bin:  17% 608M/3.50G [00:02<00:12, 235MB/s]
# pytorch_model-00002-of-00002.bin:  18% 640M/3.50G [00:02<00:11, 252MB/s]
# pytorch_model-00002-of-00002.bin:  19% 671M/3.50G [00:02<00:11, 239MB/s]
# pytorch_model-00002-of-00002.bin:  20% 703M/3.50G [00:02<00:11, 245MB/s]
# pytorch_model-00002-of-00002.bin:  21% 744M/3.50G [00:02<00:10, 268MB/s]
# pytorch_model-00002-of-00002.bin:  22% 776M/3.50G [00:03<00:11, 240MB/s]
# pytorch_model-00002-of-00002.bin:  23% 807M/3.50G [00:03<00:12, 211MB/s]
# pytorch_model-00002-of-00002.bin:  24% 839M/3.50G [00:03<00:12, 210MB/s]
# pytorch_model-00002-of-00002.bin:  25% 870M/3.50G [00:03<00:11, 220MB/s]
# pytorch_model-00002-of-00002.bin:  26% 902M/3.50G [00:06<01:08, 38.0MB/s]
# pytorch_model-00002-of-00002.bin:  27% 954M/3.50G [00:06<00:42, 60.5MB/s]
# pytorch_model-00002-of-00002.bin:  28% 986M/3.50G [00:06<00:33, 75.9MB/s]
# pytorch_model-00002-of-00002.bin:  29% 1.02G/3.50G [00:06<00:26, 93.5MB/s]
# pytorch_model-00002-of-00002.bin:  30% 1.05G/3.50G [00:06<00:21, 113MB/s]
# pytorch_model-00002-of-00002.bin:  31% 1.08G/3.50G [00:06<00:17, 137MB/s]
# pytorch_model-00002-of-00002.bin:  32% 1.12G/3.50G [00:06<00:13, 171MB/s]
# pytorch_model-00002-of-00002.bin:  33% 1.15G/3.50G [00:06<00:12, 185MB/s]
# pytorch_model-00002-of-00002.bin:  34% 1.20G/3.50G [00:07<00:10, 216MB/s]
# pytorch_model-00002-of-00002.bin:  35% 1.24G/3.50G [00:07<00:09, 242MB/s]
# pytorch_model-00002-of-00002.bin:  36% 1.27G/3.50G [00:07<00:10, 223MB/s]
# pytorch_model-00002-of-00002.bin:  37% 1.30G/3.50G [00:07<00:09, 233MB/s]
# pytorch_model-00002-of-00002.bin:  38% 1.33G/3.50G [00:07<00:09, 233MB/s]
# pytorch_model-00002-of-00002.bin:  39% 1.36G/3.50G [00:07<00:10, 204MB/s]
# pytorch_model-00002-of-00002.bin:  40% 1.39G/3.50G [00:08<00:27, 76.8MB/s]
# pytorch_model-00002-of-00002.bin:  40% 1.42G/3.50G [00:12<01:33, 22.4MB/s]
# pytorch_model-00002-of-00002.bin:  41% 1.44G/3.50G [00:12<01:14, 27.7MB/s]
# pytorch_model-00002-of-00002.bin:  42% 1.47G/3.50G [00:12<00:51, 39.6MB/s]
# pytorch_model-00002-of-00002.bin:  43% 1.51G/3.50G [00:12<00:32, 60.5MB/s]
# pytorch_model-00002-of-00002.bin:  44% 1.54G/3.50G [00:12<00:25, 78.3MB/s]
# pytorch_model-00002-of-00002.bin:  45% 1.57G/3.50G [00:12<00:19, 98.6MB/s]
# pytorch_model-00002-of-00002.bin:  46% 1.60G/3.50G [00:12<00:16, 117MB/s]
# pytorch_model-00002-of-00002.bin:  47% 1.64G/3.50G [00:13<00:13, 138MB/s]
# pytorch_model-00002-of-00002.bin:  48% 1.67G/3.50G [00:13<00:11, 158MB/s]
# pytorch_model-00002-of-00002.bin:  49% 1.71G/3.50G [00:13<00:09, 182MB/s]
# pytorch_model-00002-of-00002.bin:  50% 1.74G/3.50G [00:13<00:08, 199MB/s]
# pytorch_model-00002-of-00002.bin:  51% 1.77G/3.50G [00:13<00:08, 203MB/s]
# pytorch_model-00002-of-00002.bin:  52% 1.80G/3.50G [00:13<00:07, 218MB/s]
# pytorch_model-00002-of-00002.bin:  52% 1.84G/3.50G [00:13<00:08, 204MB/s]
# pytorch_model-00002-of-00002.bin:  53% 1.87G/3.50G [00:14<00:07, 209MB/s]
# pytorch_model-00002-of-00002.bin:  54% 1.90G/3.50G [00:14<00:07, 217MB/s]
# pytorch_model-00002-of-00002.bin:  55% 1.93G/3.50G [00:14<00:07, 218MB/s]
# pytorch_model-00002-of-00002.bin:  56% 1.96G/3.50G [00:14<00:07, 206MB/s]
# pytorch_model-00002-of-00002.bin:  57% 1.99G/3.50G [00:14<00:06, 220MB/s]
# pytorch_model-00002-of-00002.bin:  58% 2.02G/3.50G [00:15<00:13, 108MB/s]
# pytorch_model-00002-of-00002.bin:  58% 2.04G/3.50G [00:15<00:17, 84.4MB/s]
# pytorch_model-00002-of-00002.bin:  59% 2.08G/3.50G [00:15<00:13, 107MB/s]
# pytorch_model-00002-of-00002.bin:  60% 2.10G/3.50G [00:16<00:11, 117MB/s]
# pytorch_model-00002-of-00002.bin:  61% 2.12G/3.50G [00:16<00:10, 130MB/s]
# pytorch_model-00002-of-00002.bin:  61% 2.15G/3.50G [00:16<00:08, 157MB/s]
# pytorch_model-00002-of-00002.bin:  62% 2.18G/3.50G [00:16<00:07, 184MB/s]
# pytorch_model-00002-of-00002.bin:  63% 2.21G/3.50G [00:16<00:08, 143MB/s]
# pytorch_model-00002-of-00002.bin:  64% 2.24G/3.50G [00:16<00:07, 167MB/s]
# pytorch_model-00002-of-00002.bin:  65% 2.26G/3.50G [00:16<00:07, 162MB/s]
# pytorch_model-00002-of-00002.bin:  65% 2.29G/3.50G [00:17<00:07, 162MB/s]
# pytorch_model-00002-of-00002.bin:  66% 2.32G/3.50G [00:17<00:06, 182MB/s]
# pytorch_model-00002-of-00002.bin:  67% 2.36G/3.50G [00:17<00:05, 191MB/s]
# pytorch_model-00002-of-00002.bin:  68% 2.39G/3.50G [00:17<00:05, 213MB/s]
# pytorch_model-00002-of-00002.bin:  69% 2.43G/3.50G [00:17<00:04, 250MB/s]
# pytorch_model-00002-of-00002.bin:  70% 2.46G/3.50G [00:17<00:04, 242MB/s]
# pytorch_model-00002-of-00002.bin:  71% 2.50G/3.50G [00:17<00:03, 255MB/s]
# pytorch_model-00002-of-00002.bin:  72% 2.53G/3.50G [00:17<00:03, 270MB/s]
# pytorch_model-00002-of-00002.bin:  73% 2.57G/3.50G [00:18<00:03, 284MB/s]
# pytorch_model-00002-of-00002.bin:  75% 2.61G/3.50G [00:18<00:02, 299MB/s]
# pytorch_model-00002-of-00002.bin:  76% 2.65G/3.50G [00:18<00:02, 329MB/s]
# pytorch_model-00002-of-00002.bin:  77% 2.69G/3.50G [00:18<00:03, 218MB/s]
# pytorch_model-00002-of-00002.bin:  78% 2.73G/3.50G [00:18<00:04, 192MB/s]
# pytorch_model-00002-of-00002.bin:  79% 2.76G/3.50G [00:19<00:04, 171MB/s]
# pytorch_model-00002-of-00002.bin:  80% 2.80G/3.50G [00:19<00:03, 203MB/s]
# pytorch_model-00002-of-00002.bin:  81% 2.83G/3.50G [00:19<00:03, 220MB/s]
# pytorch_model-00002-of-00002.bin:  82% 2.87G/3.50G [00:19<00:02, 260MB/s]
# pytorch_model-00002-of-00002.bin:  83% 2.90G/3.50G [00:22<00:17, 34.4MB/s]
# pytorch_model-00002-of-00002.bin:  84% 2.96G/3.50G [00:22<00:10, 53.4MB/s]
# pytorch_model-00002-of-00002.bin:  86% 3.00G/3.50G [00:22<00:06, 72.8MB/s]
# pytorch_model-00002-of-00002.bin:  87% 3.04G/3.50G [00:23<00:04, 92.9MB/s]
# pytorch_model-00002-of-00002.bin:  88% 3.07G/3.50G [00:23<00:03, 111MB/s]
# pytorch_model-00002-of-00002.bin:  89% 3.11G/3.50G [00:23<00:02, 141MB/s]
# pytorch_model-00002-of-00002.bin:  90% 3.15G/3.50G [00:23<00:02, 154MB/s]
# pytorch_model-00002-of-00002.bin:  91% 3.18G/3.50G [00:26<00:10, 32.0MB/s]
# pytorch_model-00002-of-00002.bin:  92% 3.22G/3.50G [00:26<00:06, 45.8MB/s]
# pytorch_model-00002-of-00002.bin:  93% 3.25G/3.50G [00:26<00:04, 59.0MB/s]
# pytorch_model-00002-of-00002.bin:  94% 3.28G/3.50G [00:26<00:02, 74.8MB/s]
# pytorch_model-00002-of-00002.bin:  95% 3.31G/3.50G [00:26<00:01, 94.6MB/s]
# pytorch_model-00002-of-00002.bin:  96% 3.34G/3.50G [00:27<00:01, 113MB/s]
# pytorch_model-00002-of-00002.bin:  96% 3.38G/3.50G [00:27<00:00, 137MB/s]
# pytorch_model-00002-of-00002.bin:  97% 3.41G/3.50G [00:27<00:00, 162MB/s]
# pytorch_model-00002-of-00002.bin:  98% 3.44G/3.50G [00:27<00:00, 184MB/s]
# pytorch_model-00002-of-00002.bin:  99% 3.47G/3.50G [00:27<00:00, 209MB/s]
# pytorch_model-00002-of-00002.bin: 100% 3.50G/3.50G [00:27<00:00, 126MB/s]
# Downloading shards: 100% 2/2 [01:36<00:00, 48.04s/it]
# Loading checkpoint shards: 100% 2/2 [01:05<00:00, 32.68s/it]
# generation_config.json: 100% 162/162 [00:00<00:00, 778kB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# tokenizer_config.json: 100% 749/749 [00:00<00:00, 4.93MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 351MB/s]
# special_tokens_map.json: 100% 438/438 [00:00<00:00, 3.00MB/s]
# 2024-07-03 11:59:32 - Created default chainlit markdown file at /content/chainlit.md
# 2024-07-03 11:59:32 - Your app is available at http://localhost:8000
# 2024-07-03 11:59:44 - Translation file for vi not found. Using default translation en-US.
# 2024-07-03 11:59:44 - Translated markdown file for vi not found. Defaulting to chainlit.md.
# 2024-07-03 11:59:51 - Translation file for vi not found. Using default translation en-US.
# 2024-07-03 11:59:53 - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2024-07-03 11:59:58 - Translation file for vi not found. Using default translation en-US.
# 2024-07-03 12:00:13 - Translation file for vi not found. Using default translation en-US.
# 2024-07-03 12:00:21 - Translation file for vi not found. Using default translation en-US.
# 2024-07-03 12:00:23 - Translation file for vi not found. Using default translation en-US.
# 2024-07-03 12:00:24 - Translated markdown file for vi not found. Defaulting to chainlit.md.
# 2024-07-03 12:00:30 - Translation file for vi not found. Using default translation en-US.
# 2024-07-03 12:00:37 - Translation file for vi not found. Using default translation en-US.
# 2024-07-03 12:00:52 - Translation file for vi not found. Using default translation en-US.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# 2024-07-03 12:01:12 - Translation file for vi not found. Using default translation en-US.
# 2024-07-03 12:01:19 - Translation file for vi not found. Using default translation en-US.
# 2024-07-03 12:01:42 - Translation file for vi not found. Using default translation en-US.
# 2024-07-03 12:02:40 - Translation file for vi not found. Using default translation en-US.

# %%
#!chainlit run app.py  &>/content/logs.txt &
#2ifVdnJFoUTBBsPfiVisg8BMBJx_4AykwsTw4CahysQDqKFpt
